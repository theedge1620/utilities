# %%
# import necessary libraries

import pandas as pd
import xml.etree.ElementTree as ET
import requests
import os

# %%
def ADAMS_pull(document_type, year):
    # replace any spaces in the ADAMS Document type string with plus signs for the API call:
    doc_str = document_type.replace(' ','+')
    
    # construct the API link for the document type and year:
    
    API_url = 'https://adams.nrc.gov/wba/services/search/advanced/nrc?q=(mode:sections,sections:(filters:(public-library:!t),options:(within-folder:(enable:!f,insubfolder:!f,path:%27%27)),properties_search_all:!(!(DocumentType,starts,%27' + doc_str + '%27,%27%27),!(DocumentDate,range,(left:%2701/01/' + str(year) +'+12:00+AM%27,right:%2712/31/' + str(year) + '+11:59+PM%27),%27%27))))&qn=New&tab=advanced-search-pars&s=%24title&so=ASC'
    # creating HTTP response object from given url
    resp = requests.get(API_url)
    
    # save  the xml file
    with open('document_feed.xml', 'wb') as f:
        f.write(resp.content)

    # Read file and parse the xml:
    xml_data = open('document_feed.xml', 'r').read()
    root = ET.XML(xml_data)
    
    # Extract the desired elements from the xml tree:
    doc_titles = []
    doc_MLs = []
    doc_date = []
    doc_doctype = []
    doc_link = []
    for child in root.iter():
        if child.tag == 'AccessionNumber':
            doc_MLs.append(child.text)
            doc_link.append('https://www.nrc.gov/docs/'+ child.text[0:6] + '/' + child.text + '.pdf')
        elif child.tag == 'DocumentTitle':
            doc_titles.append(child.text)
        elif child.tag == 'DocumentDate':
            doc_date.append(child.text)
        elif child.tag == 'DocumentType':
            doc_doctype.append(child.text)
    
    # construct and return the desired data frame
    document_columns = ['Document Title', 'Accession Number','Document Date','Type','Link']
    doc_data = pd.DataFrame(list(zip(doc_titles,doc_MLs,doc_date,doc_doctype,doc_link)),columns = document_columns )
    
    return doc_data

# %%
# test call

LER_data = ADAMS_pull('Licensee Event Report',2021)

# %%
# display results

LER_data
# Out:
#                                         Document Title Accession Number  \
# 0    LER 2017-010-02 for Susquehanna Steam Electric...      ML21182A041
# 1    LER 2018-005-02 for Susquehanna Steam Electric...      ML21182A042
# 2    LER 2019-006-01 for Grand Gulf Nuclear Station...      ML21049A273
# 3    LER 2020-001-00 for Arkansas Nuclear One, Unit...      ML21039A557
# 4    LER 2020-001-00 for Calvert Cliffs Nuclear Pow...      ML21027A171
# 5    LER 2020-001-00 for Comanche Peak Nuclear Powe...      ML21041A178
# 6    LER 2020-001-00 for Limerick Generating Statio...      ML21012A436
# 7    LER 2020-001-00 for Vogtle Electric Generating...      ML21008A571
# 8    LER 2020-001-01 for Callaway Plant Unit 1, Eme...      ML21040A515
# 9    LER 2020-001-01 for Joseph M. Farley Nuclear P...      ML21084A234
# 10   LER 2020-001-01 for Limerick Generating Statio...      ML21078A049
# 11   LER 2020-001-01 for Susquehanna Steam Electric...      ML21026A253
# 12   LER 2020-002-00 for Clinton Power Station, Uni...      ML21063A252
# 13   LER 2020-002-00 for Limerick Generating Statio...      ML21015A017
# 14   LER 2020-002-01 for Browns Ferry Nuclear Plant...      ML21043A098
# 15   LER 2020-002-01 for Callaway Plant Unit 1, Rea...      ML21040A521
# 16   LER 2020-002-01 for Perry Nuclear Power Plant,...      ML21131A168
# 17   LER 2020-002-01 for Susquehanna Steam Electric...      ML21041A348
# 18   LER 2020-002-01 for Susquehanna, Condition Pro...      ML21182A044
# 19   LER 2020-002-01 for Turkey Point, Unit 3, Manu...      ML21064A212
# 20   LER 2020-002-02 for Grand Gulf Nuclear Station...      ML21231A135
# 21   LER 2020-003-00 for Browns Ferry Nuclear Plant...      ML21033A787
# 22   LER 2020-003-00 for Clinton Power Station, Uni...      ML21159A106
# 23   LER 2020-003-01 for Browns Ferry Nuclear Plant...      ML21092A022
# 24   LER 2020-003-01 for Grand Gulf Nuclear Station...      ML21231A136
# 25   LER 2020-003-01 for James A. FitzPatrick Nucle...      ML21251A585
# 26   LER 2020-004-00 for Watts Bar Nuclear Plant, U...      ML21007A022
# 27   LER 2020-004-01 for Donald C. Cook Nuclear Pla...      ML21063A250
# 28   LER 2020-004-01 for Grand Gulf Nuclear Station...      ML21231A137
# 29   LER 2020-005-00 for Brunswick Steam Electric P...      ML21021A366
# ..                                                 ...              ...
# 94   LER 2021-002-00 for Cooper Nuclear Station, Va...      ML21137A329
# 95   LER 2021-002-00 For Davis Besse Nuclear Power ...      ML21235A413
# 96   LER 2021-002-00 for Donald C. Cook Nuclear Pla...      ML21230A251
# 97   LER 2021-002-00 for Edwin I. Hatch, Unit 1, Lo...      ML21274A738
# 98   LER 2021-002-00 for Fermi 2 Power Plant, Unpla...      ML21294A060
# 99   LER 2021-002-00 for Grand Gulf Nuclear Station...      ML21228A259
# 100  LER 2021-002-00 for LaSalle County Station, Un...      ML21210A168
# 101  LER 2021-002-00 for Palo Verde Nuclear Generat...      ML21197A196
# 102  LER 2021-002-00 for Perry Nuclear Power re Cor...      ML21216A344
# 103  LER 2021-002-00 for River Bend Station, Unit 1...      ML21152A033
# 104  LER 2021-002-00 for Shearon Harris Nuclear Pow...      ML21046A031
# 105  LER 2021-002-00 for Susquehanna Steam Electric...      ML21301A000
# 106  LER 2021-002-00 for Susquehanna, Units 1 and 2...      ML21179A288
# 107  LER 2021-002-00 for Turkey Point, Units 3 and ...      ML21154A110
# 108  LER 2021-002-01 for LaSalle County Station, Un...      ML21266A150
# 109  LER 2021-002-01 for Shearon Harris Nuclear Pow...      ML21074A307
# 110  LER 2021-003-00 for Calvert Cliffs Nuclear Pow...      ML21266A021
# 111  LER 2021-003-00 for Catawba Nuclear Station, U...      ML21207A238
# 112  LER 2021-003-00 for Davis-Besse Nuclear Power ...      ML21250A131
# 113  LER 2021-003-00 for Edwin I. Hatch Nuclear Pla...      ML21305A874
# 114  LER 2021-003-00 for Grand Gulf Nuclear Station...      ML21308A491
# 115  LER 2021-003-00 for Sequoyah Nuclear Plant, Un...      ML21292A181
# 116  LER 2021-003-00 for Susquehanna Steam Electric...      ML21259A059
# 117  LER 2021-003-00 for Wolf Creek Generating Stat...      ML21193A078
# 118  LER 2021-004-00 for River Bend Station Unit 1,...      ML21228A240
# 96   https://www.nrc.gov/docs/ML2123/ML21230A251.pdf
# 97   https://www.nrc.gov/docs/ML2127/ML21274A738.pdf
# 98   https://www.nrc.gov/docs/ML2129/ML21294A060.pdf
# 99   https://www.nrc.gov/docs/ML2122/ML21228A259.pdf
# 100  https://www.nrc.gov/docs/ML2121/ML21210A168.pdf
# 101  https://www.nrc.gov/docs/ML2119/ML21197A196.pdf
# 102  https://www.nrc.gov/docs/ML2121/ML21216A344.pdf
# 103  https://www.nrc.gov/docs/ML2115/ML21152A033.pdf
# 104  https://www.nrc.gov/docs/ML2104/ML21046A031.pdf
# 105  https://www.nrc.gov/docs/ML2130/ML21301A000.pdf
# 106  https://www.nrc.gov/docs/ML2117/ML21179A288.pdf
# 107  https://www.nrc.gov/docs/ML2115/ML21154A110.pdf
# 108  https://www.nrc.gov/docs/ML2126/ML21266A150.pdf
# 109  https://www.nrc.gov/docs/ML2107/ML21074A307.pdf
# 110  https://www.nrc.gov/docs/ML2126/ML21266A021.pdf
# 111  https://www.nrc.gov/docs/ML2120/ML21207A238.pdf
# 112  https://www.nrc.gov/docs/ML2125/ML21250A131.pdf
# 113  https://www.nrc.gov/docs/ML2130/ML21305A874.pdf
# 114  https://www.nrc.gov/docs/ML2130/ML21308A491.pdf
# 115  https://www.nrc.gov/docs/ML2129/ML21292A181.pdf
# 116  https://www.nrc.gov/docs/ML2125/ML21259A059.pdf
# 117  https://www.nrc.gov/docs/ML2119/ML21193A078.pdf
# 118  https://www.nrc.gov/docs/ML2122/ML21228A240.pdf
# 119  https://www.nrc.gov/docs/ML2117/ML21172A009.pdf
# 120  https://www.nrc.gov/docs/ML2129/ML21291A262.pdf
# 121  https://www.nrc.gov/docs/ML2123/ML21235A012.pdf
# 122  https://www.nrc.gov/docs/ML2114/ML21141A193.pdf
# 123  https://www.nrc.gov/docs/ML2119/ML21196A485.pdf
#
# [124 rows x 5 columns]

# %%
# Load Existing OpE Document Master File:

ope_documents = pd.read_excel(os.path.expanduser("~")+'\\U.S. NRC\\ROPDashboards - Documents\\Databases\\OpE\\ope_documents_master.xlsx',sheet_name='OpE_docs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlrd\book.py in sheet_by_name(self, sheet_name)
#     473         try:
# --> 474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
#
# ValueError: 'OpE_docs' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-6-f60cb009546c> in <module>()
#       1 # Load Existing OpE Document Master File:
#       2
# ----> 3 ope_documents = pd.read_excel(os.path.expanduser("~")+'\\U.S. NRC\\ROPDashboards - Documents\\Databases\\OpE\\ope_documents_master.xlsx',sheet_name='OpE_docs')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     327         skipfooter=skipfooter,
#     328         convert_float=convert_float,
# --> 329         **kwds)
#     330
#     331
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     454                                  skipfooter=skipfooter,
#     455                                  convert_float=convert_float,
# --> 456                                  **kwds)
#     457
#     458     def _should_parse(self, i, usecols):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\excel.py in _parse_excel(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     605
#     606             if isinstance(asheetname, compat.string_types):
# --> 607                 sheet = self.book.sheet_by_name(asheetname)
#     608             else:  # assume an integer if not a string
#     609                 sheet = self.book.sheet_by_index(asheetname)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\xlrd\book.py in sheet_by_name(self, sheet_name)
#     474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
# --> 476             raise XLRDError('No sheet named <%r>' % sheet_name)
#     477         return self.sheet_by_index(sheetx)
#     478
#
# XLRDError: No sheet named <'OpE_docs'>

# %%
count = 0
keep = []
a=len(ope_documents)
for ii in range(0,len(LER_data)):
    search_ML=LER_data['Accession Number'][ii]
    if search_ML not in ope_documents.values:
        count = count+1
        keep.append(1)
    else:
        keep.append(0)
        

LER_data["Keep"] = keep
new_data = LER_data[LER_data.Keep==1]
new_data.drop('Keep', inplace=True, axis=1)
new_data
ope_documents = ope_documents.append(new_data).reset_index(drop=True)
print(count)
print(len(ope_documents)-a)

# %%
# Update Part 21s:

P21_data = ADAMS_pull('Deficiency',2021)

# %%
count = 0
keep = []
a=len(ope_documents)
for ii in range(0,len(P21_data)):
    search_ML=P21_data['Accession Number'][ii]
    if search_ML not in ope_documents.values:
        count = count+1
        keep.append(1)
    else:
        keep.append(0)
        

P21_data["Keep"] = keep
new_data = P21_data[P21_data.Keep==1]
new_data.drop('Keep', inplace=True, axis=1)
new_data
ope_documents = ope_documents.append(new_data).reset_index(drop=True)
print(count)
print(len(ope_documents)-a)

# %%
# Update Information Notices:
IN_data = ADAMS_pull('NRC INFORMATION',2021)

# %%
count = 0
keep = []
a=len(ope_documents)
for ii in range(0,len(IN_data)):
    search_ML=IN_data['Accession Number'][ii]
    if search_ML not in ope_documents.values:
        count = count+1
        keep.append(1)
    else:
        keep.append(0)
        

IN_data["Keep"] = keep
new_data = IN_data[IN_data.Keep==1]
new_data.drop('Keep', inplace=True, axis=1)
new_data
ope_documents = ope_documents.append(new_data).reset_index(drop=True)
print(count)
print(len(ope_documents)-a)

# %%
# Update Information Notices:
RIS_data = ADAMS_pull('NRC Regulatory',2021)

# %%
count = 0
keep = []
a=len(ope_documents)
for ii in range(0,len(RIS_data)):
    search_ML=RIS_data['Accession Number'][ii]
    if search_ML not in ope_documents.values:
        count = count+1
        keep.append(1)
    else:
        keep.append(0)
        

RIS_data["Keep"] = keep
new_data = RIS_data[RIS_data.Keep==1]
new_data.drop('Keep', inplace=True, axis=1)
new_data
ope_documents = ope_documents.append(new_data).reset_index(drop=True)
print(count)
print(len(ope_documents)-a)

# %%
ope_documents.to_csv(os.path.expanduser("~")+'\\U.S. NRC\\ROPDashboards - Documents\\Databases\\OpE\\ope_documents_master.tsv',sep='\t',index=False)
